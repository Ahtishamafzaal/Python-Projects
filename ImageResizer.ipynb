# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (8.4.0)

# %%
from PIL import Image
import requests
from io import BytesIO

def resize_image(image_url, width, height):
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content))
    resized_image = image.resize((width, height))
    return resized_image

# Example usage
image_url = input("Enter the image URL: ")
new_width = int(input("Enter the new width: "))
new_height = int(input("Enter the new height: "))

resized_image = resize_image(image_url, new_width, new_height)
resized_image.show()  # Display the resized image

# Save the resized image
output_path = "resized_image.jpg"
resized_image.save(output_path)
print(f"Resized image saved as {output_path}")
# Out:
# Enter the image URL: https://images.unsplash.com/photo-1621591422693-48a15c302114?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&auto=format&fit=crop&w=464&q=80
# Enter the new width: 200
# Enter the new height: 200
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FBFA87EB310>
# Resized image saved as resized_image.jpg
